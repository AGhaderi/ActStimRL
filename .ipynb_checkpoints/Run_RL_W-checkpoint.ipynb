# %%
import numpy as np
import pandas as pd
import stan
import matplotlib.pyplot as plt
import seaborn as sns
import arviz as az

# %%
# reading the RL model span
file_name = 'RL_W.stan' 
file_read = open(file_name, 'r')
stan_model = file_read.read()

# reading the observed data
examples_dir = "../data/sub-X99071_ses-01_task-DA_run-2_beh_20210422_14-27-10.csv"
df = pd.read_csv(examples_dir)
df_act = df[df.block == 'Act']


#set inistial data for molde span
data_init = {'N':int(df_act.shape[0]),     
             'pushed':np.array(df_act.pushed).astype(int),  
             'yellowChosen':np.array(df_act.yellowChosen).astype(int), 
             'winAmtPushable':np.array(df_act.winAmtPushable).astype(int), 
             'winAmtYellow':np.array(df_act.winAmtYellow).astype(int), 
             'rewarded':np.array(df_act.correctChoice).astype(int), 
             'p_push_init':.5, 
             'p_yell_init':.5}

# %%
posterior = stan.build(stan_model, data = data_init)
fit = posterior.sample(num_chains=4, num_samples=1000)
# Out:
# Building: found in cache, done.
# Messages from stanc:
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 6, column 4: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.33.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 7, column 4: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.33.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 8, column 4: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.33.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 9, column 4: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.33.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 10, column 4: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.33.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 90, column 51: The
#     variable soft_max_EV may not have been assigned a value before its use.
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 82, column 32: The
#     variable soft_max_EV may not have been assigned a value before its use.
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 78, column 27: A
#     control flow statement depends on parameter(s): bet.
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 78, column 24: A
#     control flow statement depends on parameter(s): bet.
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 43, column 65: The
#     variable p_yell may not have been assigned a value before its use.
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 43, column 24: The
#     variable p_yell may not have been assigned a value before its use.
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 42, column 59: The
#     variable p_push may not have been assigned a value before its use.
# Warning in '/tmp/httpstan_1ysrtbby/model_lmn2l45e.stan', line 42, column 24: The
#     variable p_push may not have been assigned a value before its use.
# Warning: The parameter bet has 4 priors.
# Sampling:   0%
# Sampling:  10% (800/8000)
# Sampling:  25% (2000/8000)
# Sampling:  50% (4000/8000)
# Sampling:  75% (6000/8000)
# Sampling:  90% (7200/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
#   Gradient evaluation took 7e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.7 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
# ...
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: bernoulli_lpmf: Probability parameter is -nan, but must be in the interval [0, 1] (in '/tmp/httpstan_vj502j5f/model_lmn2l45e.stan', line 82, column 8 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
p_push = fit["p_push"]  # array with shape (8, 4000)

# %%
p_push.mean(axis=1)
# Out:
# array([0.73970745, 0.82432697, 0.86769526, 0.89403621, 0.91169499,
#        0.92433437, 0.93381603, 0.94118557, 0.46765984, 0.78264824,
#        0.3897415 , 0.73735785, 0.84012414, 0.40731374, 0.26395032,
#        0.1934135 , 0.15172876, 0.12432825, 0.10500937, 0.09069253,
#        0.07967932, 0.07095815, 0.54330479, 0.2272904 , 0.13988815,
#        0.10166591, 0.08071573, 0.54697552, 0.22775218, 0.61802665,
#        0.7481031 , 0.33398535, 0.20404609, 0.14350747, 0.10948599,
#        0.08809724, 0.55300127, 0.71183189, 0.31136218, 0.18877214,
#        0.13255193, 0.10124022])

# %%
sns.displot(bet[0], bins=50)

# %%
az.summary(fit)
# Out:
#                   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha_A          0.805  0.198   0.409    1.000      0.010    0.007     468.0
# alpha_C          0.808  0.194   0.404    1.000      0.007    0.005     719.0
# weight           0.552  0.297   0.060    0.999      0.011    0.008     710.0
# bet              1.604  0.942   0.133    3.313      0.035    0.025     697.0
# p_push[0]        0.903  0.099   0.705    1.000      0.005    0.004     468.0
# ...                ...    ...     ...      ...        ...      ...       ...
# soft_max_EV[37]  1.000  0.003   1.000    1.000      0.000    0.000     914.0
# soft_max_EV[38]  0.993  0.037   0.980    1.000      0.001    0.001     881.0
# soft_max_EV[39]  1.000  0.003   1.000    1.000      0.000    0.000     916.0
# soft_max_EV[40]  1.000  0.000   1.000    1.000      0.000    0.000    1084.0
# soft_max_EV[41]  1.000  0.000   1.000    1.000      0.000    0.000    1091.0
#
#                  ess_tail  r_hat
# alpha_A             361.0   1.01
# alpha_C            1000.0   1.01
# weight              996.0   1.01
# bet                1186.0   1.01
# p_push[0]           361.0   1.01
# ...                   ...    ...
# soft_max_EV[37]    1368.0   1.00
# soft_max_EV[38]    1739.0   1.00
# soft_max_EV[39]    1280.0   1.00
# soft_max_EV[40]    1322.0   1.00
# soft_max_EV[41]    1302.0   1.00
#
# [138 rows x 9 columns]

# %%
eta = fit["eta"]  # array with shape (8, 4000)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 eta = fit["eta"]
#
# File ~/anaconda3/lib/python3.10/site-packages/stan/fit.py:132, in Fit.__getitem__(self, param)
#     130 def __getitem__(self, param):
#     131     """Returns array with shape (stan_dimensions, num_chains * num_samples)"""
# --> 132     assert param.endswith("__") or param in self.param_names, param
#     133     param_indexes = self._parameter_indexes(param)
#     134     param_dim = [] if param in self.sample_and_sampler_param_names else self.dims[self.param_names.index(param)]
#
# AssertionError: eta

# %%
eta.shape
# Out:
# (8, 4000)
