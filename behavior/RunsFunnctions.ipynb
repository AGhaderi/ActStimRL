# %%
import sys
# Add top-level folder so your package imports work
sys.path.append('/mrhome/amingk/Documents/7TPD/ActStimRL')
from utils import random, plotting, config, data_utils
import pandas as pd
import numpy as np

# %%
# pool all data from participants in one single dataframe
data_utils.build_behavior_dataframe(
                data_dir=config.PROJECT_DATA_DIR,
                beh_all_data_dir=config.PROJECT_BEH_ALL_DATA_DIR,
                raw_outfile=config.PROJECT_RAW_BEH_ALL_FILE,
                cleaned_outfile=config.PROJECT_NoNAN_BEH_ALL_FILE)
# Out:
# Both raw and cleaned data are created!

# %%
# run different strategyes with synthatic agent, used clean behavioral data to not include the no reponses
random.simStrategyBehavior(BehDir = config.PROJECT_NoNAN_BEH_ALL_FILE)

# %%
# Plot choice behavior (high-reward option proportion) across trials
plotting.plotChoicePropTrial(readBehFile= config.PROJECT_NoNAN_BEH_ALL_FILE,
                        save_path = config.FIGURES_DIR, window_size=5)

# %%
# plot of choice responce for each session and subject
plotting.plotChoiceResponseSubjects(readBehDir=config.PROJECT_DATA_DIR)
# Out:
# ✓ Saved plot for sub-057 ses-02achieva7t
# ✓ Saved plot for sub-064 ses-02achieva7t
# ✓ Saved plot for sub-064 ses-03achieva7t
# ✓ Saved plot for sub-076 ses-02achieva7t
# ✓ Saved plot for sub-076 ses-03achieva7t
# ✓ Saved plot for sub-077 ses-02achieva7t
# ✓ Saved plot for sub-077 ses-03achieva7t
# ✓ Saved plot for sub-079 ses-02achieva7t
# ✓ Saved plot for sub-079 ses-03achieva7t
# ✓ Saved plot for sub-080 ses-02achieva7t
# ✓ Saved plot for sub-080 ses-03achieva7t
# ✓ Saved plot for sub-083 ses-02achieva7t
# ✓ Saved plot for sub-083 ses-03achieva7t
# ✓ Saved plot for sub-088 ses-02achieva7t
# ✓ Saved plot for sub-088 ses-03achieva7t
# ✓ Saved plot for sub-091 ses-02achieva7t
# ✓ Saved plot for sub-121 ses-02achieva7t
# ✓ Saved plot for sub-121 ses-03achieva7t
# ✓ Saved plot for sub-004 ses-02achieva7t
# ✓ Saved plot for sub-004 ses-03achieva7t
# ✓ Saved plot for sub-010 ses-02achieva7t
# ✓ Saved plot for sub-010 ses-03achieva7t
# ✓ Saved plot for sub-041 ses-02achieva7t
# ✓ Saved plot for sub-041 ses-03achieva7t
# ✓ Saved plot for sub-005 ses-02achieva7t
# ✓ Saved plot for sub-005 ses-03achieva7t
# ✓ Saved plot for sub-040 ses-02achieva7t
# ✓ Saved plot for sub-040 ses-03achieva7t
# ✓ Saved plot for sub-029 ses-02achieva7t
# ✓ Saved plot for sub-029 ses-03achieva7t
# ✓ Saved plot for sub-045 ses-02achieva7t
# ✓ Saved plot for sub-045 ses-03achieva7t
# ✓ Saved plot for sub-042 ses-02achieva7t
# ✓ Saved plot for sub-042 ses-03achieva7t
# ✓ Saved plot for sub-052 ses-02achieva7t
# ✓ Saved plot for sub-052 ses-03achieva7t
# ✓ Saved plot for sub-059 ses-02achieva7t
# ✓ Saved plot for sub-059 ses-03achieva7t
# ✓ Saved plot for sub-025 ses-02achieva7t
# ✓ Saved plot for sub-025 ses-03achieva7t
# ✓ Saved plot for sub-056 ses-02achieva7t
# ✓ Saved plot for sub-056 ses-03achieva7t
# ✓ Saved plot for sub-065 ses-02achieva7t
# ✓ Saved plot for sub-065 ses-03achieva7t
# ✓ Saved plot for sub-070 ses-02achieva7t
# ✓ Saved plot for sub-070 ses-03achieva7t
# ✓ Saved plot for sub-071 ses-02achieva7t
# ✓ Saved plot for sub-071 ses-03achieva7t
# ✓ Saved plot for sub-074 ses-02achieva7t
# ✓ Saved plot for sub-074 ses-03achieva7t
# ✓ Saved plot for sub-082 ses-02achieva7t
# ✓ Saved plot for sub-082 ses-03achieva7t
# ✓ Saved plot for sub-085 ses-02achieva7t
# ✓ Saved plot for sub-085 ses-03achieva7t
# ✓ Saved plot for sub-086 ses-02achieva7t
# ✓ Saved plot for sub-086 ses-03achieva7t
# ✓ Saved plot for sub-087 ses-02achieva7t
# ✓ Saved plot for sub-087 ses-03achieva7t
# ✓ Saved plot for sub-089 ses-02achieva7t
# ✓ Saved plot for sub-089 ses-03achieva7t
# ✓ Saved plot for sub-092 ses-02achieva7t
# ✓ Saved plot for sub-092 ses-03achieva7t
# ✓ Saved plot for sub-108 ses-02achieva7t
# ✓ Saved plot for sub-108 ses-03achieva7t
# ✓ Saved plot for sub-106 ses-02achieva7t
# ✓ Saved plot for sub-106 ses-03achieva7t
# ✓ Saved plot for sub-109 ses-02achieva7t
# ✓ Saved plot for sub-109 ses-03achieva7t
# ✓ Saved plot for sub-012 ses-02achieva7t
# ✓ Saved plot for sub-012 ses-03achieva7t
# ✓ Saved plot for sub-036 ses-02achieva7t
# ✓ Saved plot for sub-036 ses-03achieva7t
# ✓ Saved plot for sub-026 ses-02achieva7t
# ✓ Saved plot for sub-026 ses-03achieva7t
# ✓ Saved plot for sub-034 ses-02achieva7t
# ✓ Saved plot for sub-034 ses-03achieva7t
# ✓ Saved plot for sub-033 ses-02achieva7t
# ✓ Saved plot for sub-033 ses-03achieva7t
# ✓ Saved plot for sub-044 ses-02achieva7t
# ✓ Saved plot for sub-044 ses-03achieva7t
# ✓ Saved plot for sub-030 ses-02achieva7t
# ✓ Saved plot for sub-030 ses-03achieva7t
# ✓ Saved plot for sub-047 ses-02achieva7t
# ✓ Saved plot for sub-047 ses-03achieva7t
# ✓ Saved plot for sub-054 ses-02achieva7t
# ✓ Saved plot for sub-054 ses-03achieva7t
# ✓ Saved plot for sub-048 ses-02achieva7t
# ✓ Saved plot for sub-048 ses-03achieva7t
# ✓ Saved plot for sub-067 ses-02achieva7t
# ✓ Saved plot for sub-067 ses-03achieva7t
# ✓ Saved plot for sub-060 ses-02achieva7t
# ✓ Saved plot for sub-060 ses-03achieva7t
# ✓ Saved plot for sub-069 ses-02achieva7t
# ✓ Saved plot for sub-069 ses-03achieva7t
# ✓ Saved plot for sub-075 ses-02achieva7t
# ✓ Saved plot for sub-075 ses-03achieva7t
# ✓ Saved plot for sub-078 ses-02achieva7t
# ✓ Saved plot for sub-078 ses-03achieva7t
# ✓ Saved plot for sub-081 ses-02achieva7t
# ✓ Saved plot for sub-081 ses-03achieva7t
# ✓ Saved plot for sub-090 ses-02achieva7t
# ✓ Saved plot for sub-090 ses-03achieva7t

# %%
# plot the bias of each figure in the task
plotting.plotFeatureBias(readBehFile=config.PROJECT_NoNAN_BEH_ALL_FILE,
                         saveFigPath=config.FIGURES_DIR)
