# %%
import numpy as np
import pandas as pd
import stan
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/mrhome/amingk/Documents/7TPD/ActStimRL')
from Madule import utils, plots
import arviz as az

# %% [markdown]
# ### Model 1

# %%
# Directory of pickle file
pickelDir = '/mnt/projects/7TPD/bids/derivatives/fMRI_DA/data_BehModel/originalfMRIbehFiles/Model_secondOrder/hier/sim/simulation_chosing_higher_amount_Model1.pkl'
"""Loading the pickle file of model fit from the subject directory"""
loadPkl = utils.load_pickle(load_path=pickelDir)
fit = loadPkl['fit']

# %%
az.summary(fit)[0:5]
# Out:
# /mrhome/amingk/anaconda3/envs/7tpd/lib/python3.9/site-packages/arviz/stats/diagnostics.py:592: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /mrhome/amingk/anaconda3/envs/7tpd/lib/python3.9/site-packages/arviz/stats/diagnostics.py:592: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /mrhome/amingk/anaconda3/envs/7tpd/lib/python3.9/site-packages/arviz/stats/diagnostics.py:592: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /mrhome/amingk/anaconda3/envs/7tpd/lib/python3.9/site-packages/arviz/stats/diagnostics.py:592: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# ...

# %%
log_lik = fit['log_lik']
utils.waic(log_likelihood=log_lik)
# Out:
# {'lppd': -5.3043110762193475,
#  'p_waic': 0.6275306448622359,
#  'waic': 11.863683442163167,
#  'waic_se': 0.03414993011458304}

# %% [markdown]
# ### Model 2

# %%
# Directory of pickle file
pickelDir = '/mnt/projects/7TPD/bids/derivatives/fMRI_DA/data_BehModel/originalfMRIbehFiles/Model_secondOrder/hier/sim/simulation_chosing_higher_probability_Model1.pkl'
"""Loading the pickle file of model fit from the subject directory"""
loadPkl = utils.load_pickle(load_path=pickelDir)
fit = loadPkl['fit']

# %%
az.summary(fit)[0:5]
# Out:
#                          mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# hier_alphaAct_mu[0, 0] -0.247  0.075  -0.386   -0.104      0.000    0.000
# hier_alphaAct_mu[0, 1] -0.022  0.986  -1.888    1.804      0.005    0.007
# hier_alphaAct_mu[1, 0] -0.229  0.078  -0.373   -0.079      0.000    0.000
# hier_alphaAct_mu[1, 1]  0.049  1.000  -1.823    1.930      0.005    0.007
# hier_alphaClr_mu[0, 0] -0.021  0.999  -1.833    1.911      0.006    0.007
#
#                         ess_bulk  ess_tail  r_hat
# hier_alphaAct_mu[0, 0]   28424.0   17839.0    1.0
# hier_alphaAct_mu[0, 1]   35410.0   18663.0    1.0
# hier_alphaAct_mu[1, 0]   28951.0   17713.0    1.0
# hier_alphaAct_mu[1, 1]   38980.0   17295.0    1.0
# hier_alphaClr_mu[0, 0]   32069.0   18403.0    1.0

# %%
log_lik = fit['log_lik']
utils.waic(log_likelihood=log_lik)
# Out:
# {'lppd': -14326.203852994095,
#  'p_waic': 2961.490016998277,
#  'waic': 34575.38773998474,
#  'waic_se': 1.0750751854584937}

# %% [markdown]
# ### Model 3

# %%
# Directory of pickle file
pickelDir = '/mnt/projects/7TPD/bids/derivatives/fMRI_DA/data_BehModel/originalfMRIbehFiles/Model_secondOrder/hier/para_recov/simulation_chosing_left_right_Model1.pkl'
"""Loading the pickle file of model fit from the subject directory"""
loadPkl = utils.load_pickle(load_path=pickelDir)
fit = loadPkl['fit']

# %%
az.summary(fit)[0:5]
# Out:
#                          mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# hier_alphaAct_mu[0, 0] -0.020  0.994  -1.822    1.913      0.005    0.007
# hier_alphaAct_mu[0, 1]  0.021  0.996  -1.834    1.916      0.005    0.007
# hier_alphaAct_mu[1, 0] -0.052  1.006  -1.895    1.888      0.005    0.007
# hier_alphaAct_mu[1, 1] -0.019  0.992  -1.935    1.801      0.005    0.007
# hier_alphaClr_mu[0, 0] -0.129  1.024  -2.037    1.748      0.005    0.008
#
#                         ess_bulk  ess_tail  r_hat
# hier_alphaAct_mu[0, 0]   43406.0   18002.0    1.0
# hier_alphaAct_mu[0, 1]   42328.0   17592.0    1.0
# hier_alphaAct_mu[1, 0]   45961.0   17604.0    1.0
# hier_alphaAct_mu[1, 1]   39344.0   17087.0    1.0
# hier_alphaClr_mu[0, 0]   41724.0   16631.0    1.0

# %%
log_lik = fit['log_lik']
utils.waic(log_likelihood=log_lik)
# Out:
# {'lppd': -17327.261837295304,
#  'p_waic': 4.062191409185228,
#  'waic': 34662.64805740898,
#  'waic_se': 0.04085718548411488}
